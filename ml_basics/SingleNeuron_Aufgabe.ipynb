# %% [markdown]
# <a href="https://colab.research.google.com/github/kampelmuehler/MLKurs/blob/main/ml_basics/SingleNeuron_Aufgabe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementieren Sie ein einzelnes Neuron indem Sie die Vorlage vervollständigen.
#
# Zur Erinnerung:
# $y = f(w_1x_1+...+w_nx_n + b) = f(W^TX + b)$
#
# Verwenden Sie die selben Werte wie im numerischen Beispiel + ReLU $f(x) = \text{max}(x, 0)$ als Aktivierunsfunktion
# ![grafik.png](data:image/png;base64,...)

# %%
import numpy as np

class Neuron():
  def __init__(self, w, b):
    self.weights = w
    self.bias = b

  def forward(self, x):
    pass

  def backward(self, grad):
    pass

n11= Neuron()
h11 = n11.forward()
print(h11, n11.backward(1))
n12 = Neuron()
h12 = n12.forward()
print(h12, n12.backward(1))
n2 = Neuron()
y = n2.forward()
print(y, n2.backward(1))
